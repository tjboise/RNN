# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPRegressor
import seaborn as sns
from census import Census
import statsmodels.formula.api as smf
import statsmodels.api as sm
import scipy.stats as sps
from sklearn.preprocessing import FunctionTransformer, OneHotEncoder, StandardScaler, PolynomialFeatures
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression, ElasticNetCV,LogisticRegression
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.metrics import mean_squared_error,accuracy_score,precision_score,classification_report,confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
from sklearn.impute import SimpleImputer
import sklearn
import warnings
warnings.filterwarnings("ignore")
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %% [markdown]
# ## Preprocessing

# %%
df = pd.read_csv('../training_data/final_data.csv')
df
# Out:
#       SHRP_ID  STATE_CODE  VISIT_DATE  IRI_LEFT_WHEEL_PATH  \
# 0        0001          48  1990-03-06               0.6904
# 1        0001          48  1992-03-17               0.6894
# 2        0001          48  1993-07-13               0.7472
# 3        0001          48  1995-05-03               0.7092
# 4        0001          48  1997-08-06               0.7600
# ...       ...         ...         ...                  ...
# 29765    Q350          48  1995-05-01               1.2042
# 29766    Q350          48  2001-04-18               1.1592
# 29767    Q353          48  1990-09-17               1.1030
# 29768    Q353          48  1995-05-01               1.2294
# 29769    Q353          48  2001-04-18               1.1338
#
#        IRI_RIGHT_WHEEL_PATH  MAX_ANN_HUM_AVG  MIN_ANN_HUM_AVG  \
# 0                    0.6570        89.222222        44.814815
# 1                    0.7312        89.222222        44.814815
# 2                    0.6938        89.222222        44.814815
# 3                    0.7838        89.222222        44.814815
# 4                    0.7508        89.222222        44.814815
# ...                     ...              ...              ...
# 29765                1.1674        88.333333        43.666667
# 29766                1.0578        88.333333        43.666667
# 29767                0.7784        88.333333        43.666667
# 29768                1.0444        88.333333        43.666667
# 29769                0.9110        88.333333        43.666667
#
#        MEAN_ANN_TEMP_AVG  FREEZE_THAW_YR  TOTAL_ANN_PRECIP  TOTAL_SNOWFALL_YR  \
# 0              20.363636       15.303030        859.939394          12.424242
# 1              20.363636       15.303030        859.939394          12.424242
# 2              20.363636       15.303030        859.939394          12.424242
# 3              20.363636       15.303030        859.939394          12.424242
# 4              20.363636       15.303030        859.939394          12.424242
# ...                  ...             ...               ...                ...
# 29765          18.636364       36.295455        743.522727          15.431818
# 29766          18.636364       36.295455        743.522727          15.431818
# 29767          18.636364       36.295455        743.522727          15.431818
# 29768          18.636364       36.295455        743.522727          15.431818
# 29769          18.636364       36.295455        743.522727          15.431818
#
#        AADT_ALL_VEHIC  MEPDG_TRANS_CRACK_LENGTH_AC
# 0           -1.000000                    12.881818
# 1           -1.000000                    12.881818
# 2           -1.000000                    12.881818
# 3           -1.000000                    12.881818
# 4           -1.000000                    12.881818
# ...               ...                          ...
# 29765     1158.809524                    -1.000000
# 29766     1158.809524                    -1.000000
# 29767     1158.809524                     2.183333
# 29768     1158.809524                     2.183333
# 29769     1158.809524                     2.183333
#
# [29770 rows x 13 columns]

# %%
df = pd.read_csv('../training_data/final_data.csv')
df['IRI_LEFT_WHEEL_PATH'].value_counts()

df['Mean_IRI'] = 0.5*(df['IRI_LEFT_WHEEL_PATH']+df['IRI_RIGHT_WHEEL_PATH'])

df['Mean_IRI'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
# df.loc[df['Mean_IRI'] <= 1.50, 'IRI_condition'] = 2#'good'
# df.loc[(df['Mean_IRI'] > 1.50) & (df['Mean_IRI'] <= 2.68), 'IRI_condition'] = 1#'acceptable'
# df.loc[df['Mean_IRI'] > 2.68, 'IRI_condition'] = 0#'poor'
# df['IRI_condition'].hist()

# %%
df
# Out:
#       SHRP_ID  STATE_CODE  VISIT_DATE  IRI_LEFT_WHEEL_PATH  \
# 0        0001          48  1990-03-06               0.6904
# 1        0001          48  1992-03-17               0.6894
# 2        0001          48  1993-07-13               0.7472
# 3        0001          48  1995-05-03               0.7092
# 4        0001          48  1997-08-06               0.7600
# ...       ...         ...         ...                  ...
# 29765    Q350          48  1995-05-01               1.2042
# 29766    Q350          48  2001-04-18               1.1592
# 29767    Q353          48  1990-09-17               1.1030
# 29768    Q353          48  1995-05-01               1.2294
# 29769    Q353          48  2001-04-18               1.1338
#
#        IRI_RIGHT_WHEEL_PATH  MAX_ANN_HUM_AVG  MIN_ANN_HUM_AVG  \
# 0                    0.6570        89.222222        44.814815
# 1                    0.7312        89.222222        44.814815
# 2                    0.6938        89.222222        44.814815
# 3                    0.7838        89.222222        44.814815
# 4                    0.7508        89.222222        44.814815
# ...                     ...              ...              ...
# 29765                1.1674        88.333333        43.666667
# 29766                1.0578        88.333333        43.666667
# 29767                0.7784        88.333333        43.666667
# 29768                1.0444        88.333333        43.666667
# 29769                0.9110        88.333333        43.666667
#
#        MEAN_ANN_TEMP_AVG  FREEZE_THAW_YR  TOTAL_ANN_PRECIP  TOTAL_SNOWFALL_YR  \
# 0              20.363636       15.303030        859.939394          12.424242
# 1              20.363636       15.303030        859.939394          12.424242
# 2              20.363636       15.303030        859.939394          12.424242
# 3              20.363636       15.303030        859.939394          12.424242
# 4              20.363636       15.303030        859.939394          12.424242
# ...                  ...             ...               ...                ...
# 29765          18.636364       36.295455        743.522727          15.431818
# 29766          18.636364       36.295455        743.522727          15.431818
# 29767          18.636364       36.295455        743.522727          15.431818
# 29768          18.636364       36.295455        743.522727          15.431818
# 29769          18.636364       36.295455        743.522727          15.431818
#
#        AADT_ALL_VEHIC  MEPDG_TRANS_CRACK_LENGTH_AC  Mean_IRI
# 0           -1.000000                    12.881818    0.6737
# 1           -1.000000                    12.881818    0.7103
# 2           -1.000000                    12.881818    0.7205
# 3           -1.000000                    12.881818    0.7465
# 4           -1.000000                    12.881818    0.7554
# ...               ...                          ...       ...
# 29765     1158.809524                    -1.000000    1.1858
# 29766     1158.809524                    -1.000000    1.1085
# 29767     1158.809524                     2.183333    0.9407
# 29768     1158.809524                     2.183333    1.1369
# 29769     1158.809524                     2.183333    1.0224
#
# [29770 rows x 14 columns]

# %%
df['VISIT_DATE'] = pd.to_datetime(df['VISIT_DATE'])
df['year'] = df['VISIT_DATE'].dt.strftime('%Y')
df['construction_time'] = 2022 - df['year'].astype(int)
# df = df[['STATE_CODE','AADT_ALL_VEHIC','MEPDG_TRANS_CRACK_LENGTH_AC','construction_time','Mean_IRI']]
df
# Out:
#       SHRP_ID  STATE_CODE VISIT_DATE  IRI_LEFT_WHEEL_PATH  \
# 0        0001          48 1990-03-06               0.6904
# 1        0001          48 1992-03-17               0.6894
# 2        0001          48 1993-07-13               0.7472
# 3        0001          48 1995-05-03               0.7092
# 4        0001          48 1997-08-06               0.7600
# ...       ...         ...        ...                  ...
# 29765    Q350          48 1995-05-01               1.2042
# 29766    Q350          48 2001-04-18               1.1592
# 29767    Q353          48 1990-09-17               1.1030
# 29768    Q353          48 1995-05-01               1.2294
# 29769    Q353          48 2001-04-18               1.1338
#
#        IRI_RIGHT_WHEEL_PATH  MAX_ANN_HUM_AVG  MIN_ANN_HUM_AVG  \
# 0                    0.6570        89.222222        44.814815
# 1                    0.7312        89.222222        44.814815
# 2                    0.6938        89.222222        44.814815
# 3                    0.7838        89.222222        44.814815
# 4                    0.7508        89.222222        44.814815
# ...                     ...              ...              ...
# 29765                1.1674        88.333333        43.666667
# 29766                1.0578        88.333333        43.666667
# 29767                0.7784        88.333333        43.666667
# 29768                1.0444        88.333333        43.666667
# 29769                0.9110        88.333333        43.666667
#
#        MEAN_ANN_TEMP_AVG  FREEZE_THAW_YR  TOTAL_ANN_PRECIP  TOTAL_SNOWFALL_YR  \
# 0              20.363636       15.303030        859.939394          12.424242
# 1              20.363636       15.303030        859.939394          12.424242
# 2              20.363636       15.303030        859.939394          12.424242
# 3              20.363636       15.303030        859.939394          12.424242
# 4              20.363636       15.303030        859.939394          12.424242
# ...                  ...             ...               ...                ...
# 29765          18.636364       36.295455        743.522727          15.431818
# 29766          18.636364       36.295455        743.522727          15.431818
# 29767          18.636364       36.295455        743.522727          15.431818
# 29768          18.636364       36.295455        743.522727          15.431818
# 29769          18.636364       36.295455        743.522727          15.431818
#
#        AADT_ALL_VEHIC  MEPDG_TRANS_CRACK_LENGTH_AC  Mean_IRI  year  \
# 0           -1.000000                    12.881818    0.6737  1990
# 1           -1.000000                    12.881818    0.7103  1992
# 2           -1.000000                    12.881818    0.7205  1993
# 3           -1.000000                    12.881818    0.7465  1995
# 4           -1.000000                    12.881818    0.7554  1997
# ...               ...                          ...       ...   ...
# 29765     1158.809524                    -1.000000    1.1858  1995
# 29766     1158.809524                    -1.000000    1.1085  2001
# 29767     1158.809524                     2.183333    0.9407  1990
# 29768     1158.809524                     2.183333    1.1369  1995
# 29769     1158.809524                     2.183333    1.0224  2001
#
#        construction_time
# 0                     32
# 1                     30
# 2                     29
# 3                     27
# 4                     25
# ...                  ...
# 29765                 27
# 29766                 21
# 29767                 32
# 29768                 27
# 29769                 21
#
# [29770 rows x 16 columns]

# %%
# from sklearn.preprocessing import MinMaxScaler
# scaler = MinMaxScaler()
# AADT = df['AADT_ALL_VEHIC'].values.reshape(-1, 1)
# AADT = scaler.fit_transform(AADT)
# df['AADT_ALL_VEHIC'] = AADT

# df

# %%
df.to_csv('preprocessed_data.csv',index='False')
