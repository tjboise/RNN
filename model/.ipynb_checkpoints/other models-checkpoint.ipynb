# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPRegressor
import seaborn as sns
from census import Census
import statsmodels.formula.api as smf
import statsmodels.api as sm
import scipy.stats as sps
from sklearn.preprocessing import FunctionTransformer, OneHotEncoder, StandardScaler, PolynomialFeatures
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression, ElasticNetCV,LogisticRegression
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.metrics import mean_squared_error,accuracy_score,precision_score,classification_report,confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
from sklearn.impute import SimpleImputer
import sklearn
import warnings
warnings.filterwarnings("ignore")
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
def metric_count(y,y_hat):
    acc = accuracy_score(y,y_hat)
    precision = precision_score(y,y_hat, average='macro')
    recall = recall_score(y,y_hat, average='macro')
    f1 = f1_score(y,y_hat, average='macro')

    return print('acc:',acc,'pre:',precision,'re',recall, 'f1',f1)

# %% [markdown]
# ## Preprocessing

# %%
df = pd.read_csv('../training_data/final_data.csv')
df
# Out:
#       SHRP_ID  STATE_CODE  VISIT_DATE  IRI_LEFT_WHEEL_PATH  \
# 0        0001          48  1990-03-06               0.6904
# 1        0001          48  1992-03-17               0.6894
# 2        0001          48  1993-07-13               0.7472
# 3        0001          48  1995-05-03               0.7092
# 4        0001          48  1997-08-06               0.7600
# ...       ...         ...         ...                  ...
# 29765    Q350          48  1995-05-01               1.2042
# 29766    Q350          48  2001-04-18               1.1592
# 29767    Q353          48  1990-09-17               1.1030
# 29768    Q353          48  1995-05-01               1.2294
# 29769    Q353          48  2001-04-18               1.1338
#
#        IRI_RIGHT_WHEEL_PATH  AADT_ALL_VEHIC  MEPDG_TRANS_CRACK_LENGTH_AC
# 0                    0.6570       -1.000000                    12.881818
# 1                    0.7312       -1.000000                    12.881818
# 2                    0.6938       -1.000000                    12.881818
# 3                    0.7838       -1.000000                    12.881818
# 4                    0.7508       -1.000000                    12.881818
# ...                     ...             ...                          ...
# 29765                1.1674     1158.809524                    -1.000000
# 29766                1.0578     1158.809524                    -1.000000
# 29767                0.7784     1158.809524                     2.183333
# 29768                1.0444     1158.809524                     2.183333
# 29769                0.9110     1158.809524                     2.183333
#
# [29770 rows x 7 columns]

# %%
df = pd.read_csv('../training_data/final_data.csv')
df['IRI_LEFT_WHEEL_PATH'].value_counts()

df['Mean_IRI'] = 0.5*(df['IRI_LEFT_WHEEL_PATH']+df['IRI_RIGHT_WHEEL_PATH'])

df['Mean_IRI'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
df.loc[df['Mean_IRI'] <= 1.50, 'IRI_condition'] = 2#'good'
df.loc[(df['Mean_IRI'] > 1.50) & (df['Mean_IRI'] <= 2.68), 'IRI_condition'] = 1#'acceptable'
df.loc[df['Mean_IRI'] > 2.68, 'IRI_condition'] = 0#'poor'
df['IRI_condition'].hist()
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#       SHRP_ID  STATE_CODE  VISIT_DATE  IRI_LEFT_WHEEL_PATH  \
# 0        0001          48  1990-03-06               0.6904
# 1        0001          48  1992-03-17               0.6894
# 2        0001          48  1993-07-13               0.7472
# 3        0001          48  1995-05-03               0.7092
# 4        0001          48  1997-08-06               0.7600
# ...       ...         ...         ...                  ...
# 29765    Q350          48  1995-05-01               1.2042
# 29766    Q350          48  2001-04-18               1.1592
# 29767    Q353          48  1990-09-17               1.1030
# 29768    Q353          48  1995-05-01               1.2294
# 29769    Q353          48  2001-04-18               1.1338
#
#        IRI_RIGHT_WHEEL_PATH  AADT_ALL_VEHIC  MEPDG_TRANS_CRACK_LENGTH_AC  \
# 0                    0.6570       -1.000000                    12.881818
# 1                    0.7312       -1.000000                    12.881818
# 2                    0.6938       -1.000000                    12.881818
# 3                    0.7838       -1.000000                    12.881818
# 4                    0.7508       -1.000000                    12.881818
# ...                     ...             ...                          ...
# 29765                1.1674     1158.809524                    -1.000000
# 29766                1.0578     1158.809524                    -1.000000
# 29767                0.7784     1158.809524                     2.183333
# 29768                1.0444     1158.809524                     2.183333
# 29769                0.9110     1158.809524                     2.183333
#
#        Mean_IRI  IRI_condition
# 0        0.6737            2.0
# 1        0.7103            2.0
# 2        0.7205            2.0
# 3        0.7465            2.0
# 4        0.7554            2.0
# ...         ...            ...
# 29765    1.1858            2.0
# 29766    1.1085            2.0
# 29767    0.9407            2.0
# 29768    1.1369            2.0
# 29769    1.0224            2.0
#
# [29770 rows x 9 columns]

# %%
df['VISIT_DATE'] = pd.to_datetime(df['VISIT_DATE'])
df['year'] = df['VISIT_DATE'].dt.strftime('%Y')
df['construction_time'] = 2022 - df['year'].astype(int)
# Out:
#       SHRP_ID  STATE_CODE VISIT_DATE  IRI_LEFT_WHEEL_PATH  \
# 0        0001          48 1990-03-06               0.6904
# 1        0001          48 1992-03-17               0.6894
# 2        0001          48 1993-07-13               0.7472
# 3        0001          48 1995-05-03               0.7092
# 4        0001          48 1997-08-06               0.7600
# ...       ...         ...        ...                  ...
# 29765    Q350          48 1995-05-01               1.2042
# 29766    Q350          48 2001-04-18               1.1592
# 29767    Q353          48 1990-09-17               1.1030
# 29768    Q353          48 1995-05-01               1.2294
# 29769    Q353          48 2001-04-18               1.1338
#
#        IRI_RIGHT_WHEEL_PATH  AADT_ALL_VEHIC  MEPDG_TRANS_CRACK_LENGTH_AC  \
# 0                    0.6570       -1.000000                    12.881818
# 1                    0.7312       -1.000000                    12.881818
# 2                    0.6938       -1.000000                    12.881818
# 3                    0.7838       -1.000000                    12.881818
# 4                    0.7508       -1.000000                    12.881818
# ...                     ...             ...                          ...
# 29765                1.1674     1158.809524                    -1.000000
# 29766                1.0578     1158.809524                    -1.000000
# 29767                0.7784     1158.809524                     2.183333
# 29768                1.0444     1158.809524                     2.183333
# 29769                0.9110     1158.809524                     2.183333
#
#        Mean_IRI  IRI_condition  year  construction_time
# 0        0.6737            2.0  1990                 32
# 1        0.7103            2.0  1992                 30
# 2        0.7205            2.0  1993                 29
# 3        0.7465            2.0  1995                 27
# 4        0.7554            2.0  1997                 25
# ...         ...            ...   ...                ...
# 29765    1.1858            2.0  1995                 27
# 29766    1.1085            2.0  2001                 21
# 29767    0.9407            2.0  1990                 32
# 29768    1.1369            2.0  1995                 27
# 29769    1.0224            2.0  2001                 21
#
# [29770 rows x 11 columns]

# %% [markdown]
# There are a lot roads whose IRI is equal to 1 or 2 or 3. is it normal?
#
# In an ideal scenario where the road surface is perfectly smooth, the International Roughness Index (IRI) would be zero. However, in practice, it is challenging to achieve a completely smooth road surface due to various factors such as construction tolerances, material properties, and environmental conditions. Thus, we need to eliminate the 0 value.
#
# - The IRI values are calculated based on the longitudinal profile of the road and are typically reported in units of meters per kilometer (m/km) or inches per mile (in/mi).
#
# - The higher the IRI value, the rougher the road surface, and vice versa

# %%
df.to_csv()

# %%
train, test = train_test_split(df, test_size=0.25, random_state=12345)

# %%
feat_cols = ['AADT_ALL_VEHIC','construction_time', 'MEPDG_TRANS_CRACK_LENGTH_AC']
out_col = 'Mean_IRI'
train_x = train[feat_cols]
train_y = train[out_col]

# %% [markdown]
# ## LogisticRegression

# %%
lm_pipe = Pipeline([
#     ('columns', ColumnTransformer([
#         ('AADT',StandardScaler(),'AADT_ALL_VEHIC'),
#         ('Crack',StandardScaler(),'MEPDG_TRANS_CRACK_LENGTH_AC')
#     ])),
    ('model', LogisticRegression(class_weight='balanced',penalty='none'))
])
lm_pipe.fit(train_x,train_y)
metric_count(train_y,lm_pipe.predict(train_x))
# Out:
# acc: 0.3923500694226721 pre: 0.37872478197849685 re 0.39013746305270214 f1 0.3026383435981902

# %%
la_pipe = Pipeline([
#     ('columns', ColumnTransformer([
#         ('AADT',StandardScaler(),'AADT_ALL_VEHIC'),
#         ('Crack',StandardScaler(),'MEPDG_TRANS_CRACK_LENGTH_AC')
#     ])),
    ('model', LogisticRegression(class_weight='balanced',penalty='l1',solver='liblinear'))
])
la_pipe.fit(train_x,train_y)
metric_count(train_y,la_pipe.predict(train_x))
# Out:
# acc: 0.6295516639046894 pre: 0.5853609240537727 re 0.3534429644762435 f1 0.2927982766024503

# %%
en_pipe = Pipeline([
#     ('columns', ColumnTransformer([
#         ('AADT',StandardScaler(),'AADT_ALL_VEHIC'),
#         ('Crack',StandardScaler(),'MEPDG_TRANS_CRACK_LENGTH_AC')
#     ])),
    ('model', LogisticRegression(class_weight='balanced',penalty='l2',solver='saga'))
])
en_pipe.fit(train_x,train_y)
metric_count(train_y,en_pipe.predict(train_x))
# Out:
# acc: 0.2764366014242845 pre: 0.39073331336209316 re 0.38368592460826756 f1 0.245496193051588

# %%
rm_pipe = Pipeline([
#     ('columns', ColumnTransformer([
#         ('AADT',StandardScaler(),'AADT_ALL_VEHIC'),
#         ('Crack',StandardScaler(),'MEPDG_TRANS_CRACK_LENGTH_AC')
#     ])),
    ('model', RandomForestClassifier(class_weight='balanced',n_estimators=100))
])
rm_pipe.fit(train_x,train_y)
metric_count(train_y,rm_pipe.predict(train_x))
# Out:
# acc: 0.8633940968334304 pre: 0.8032208667844533 re 0.8742024576506505 f1 0.8314990897478545

# %% [markdown]
# ### regression

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
rm_pipe = Pipeline([
#     ('columns', ColumnTransformer([
#         ('AADT',StandardScaler(),'AADT_ALL_VEHIC'),
#         ('Crack',StandardScaler(),'MEPDG_TRANS_CRACK_LENGTH_AC')
#     ])),
    ('model', RandomForestRegressor(max_depth=5, random_state=0,n_estimators=100))
])
rm_pipe.fit(train_x,train_y)
mse = mean_squared_error(train_y,rm_pipe.predict(train_x))
mse
# Out:
# 0.2750652856906324
